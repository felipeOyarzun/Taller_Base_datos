# %% [markdown]
# # TP2- Introducción al SGBD MongoDB y Conexión a la API Rest de Twitter

# %% [markdown]
# En este trabajo práctico queremos descubrir las características del SGBD no relacional MongoDB. En este sentido, vamos a desarrollar un script que se conecta a la API Rest de Twitter para: 1) descargar datos al formato JSON, 2) almacenarlos en una base Mongo y 3) realizar algunas consultas sobre los datos.

# %% [markdown]
# ## 1. Conectarse a la API Rest de Twitter

# %% [markdown]
# - ¿Cómo crear una aplicación utilizando los datos de Twitter?: https://developer.twitter.com/en/docs/basics/getting-started
# - Crear una aplicación utilizando los datos de Twitter: https://apps.twitter.com/
# - ¿Qué deberían saber todos los desarrolladores antes de jugar con la API de twitter?: https://developer.twitter.com/en/docs/basics/things-every-developer-should-know

# %%
from twython import Twython
twitter = Twython("SQwlAvJEHxoE0dW3yi2Iyn5ZD", 
                  "TPDE1a1hIn8AA7vWvmot1mac09be2HdpzdPrnpN8Ga132izSHN",
                  "75908426-Iddd3R9RwyA582cFEKziw76MViSor9oYYM0TkAgVl",
                  "UzQ3z2g2OeRRHAuPoFRBqWvPCFEcauwJuFvyyK4rmU4cj")

# %% [markdown]
# ## 2. Consultar la API de Twitter

# %% [markdown]
# - Utilizando una librería Python que permite enviar consultas HTTP a la API de Twitter, conectarse a un 'endpoint' de la API para leer datos. Ver la lista de los endpoints: https://developer.twitter.com/en/docs/tweets/post-and-engage/overview

# %%
results = twitter.search(q='valdivia')
for i in range(14):
    Text = results["statuses"][i]["text"]
    Date = results["statuses"][i]["created_at"]
    
Text = results["statuses"][0]["text"]
Date = results["statuses"][0]["created_at"]
UserName=results["statues"][0]["name"]
Location=results["statuses"][0]["location"]




Json={"Text":Text, "Date":Date, UserName:"UserName",Location:"Location"}
print (Json)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-ef71869170a6> in <module>()
#       6 Text = results["statuses"][0]["text"]
#       7 Date = results["statuses"][0]["created_at"]
# ----> 8 UserName=results["statues"][0]["name"]
#       9 Location=results["statuses"][0]["location"]
#      10
#
# KeyError: 'statues'

# %%
print(results)
# Out:
# {'statuses': [{'created_at': 'Mon Apr 09 20:39:08 +0000 2018', 'id': 983444221989400579, 'id_str': '983444221989400579', 'text': 'RT @Holtzman_U: Jueves: Paredes Y Valdes en en duda por contracturas, Barroso no iría de titular, Valdivia y Johnny calientan el clásico.\nS…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Holtzman_U', 'name': 'Danielle', 'id': 4788077655, 'id_str': '4788077655', 'indices': [3, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'es', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2149153289, 'id_str': '2149153289', 'name': 'Contra todo y todos', 'screen_name': 'Ariel11Juan', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 777, 'friends_count': 1211, 'listed_count': 5, 'created_at': 'Wed Oct 23 03:31:15 +0000 2013', 'favourites_count': 3125, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 3273, 'lang': 'es', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/785727553898213376/It5FGdaU_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/785727553898213376/It5FGdaU_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2149153289/1417957332', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Apr 09 01:04:21 +0000 2018', 'id': 983148577420541952, 'id_str': '983148577420541952', 'text': 'Jueves: Paredes Y Valdes en en duda por contracturas, Barroso no iría de titular, Valdivia y Johnny calientan el cl… https://t.co/nQeq4gaptc', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/nQeq4gaptc', 'expanded_url': 'https://twitter.com/i/web/status/983148577420541952', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'es', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 4788077655, 'id_str': '4788077655', 'name': 'Danielle', 'screen_name': 'Holtzman_U', 'location': 'Friendship, Chiloé, Los Lagos.', 'description': 'Pesá |   \U0001f9d9\u200d♀️⚡️ | Draco dormiens nunquam titillandus  | 🤘de 🇨🇱', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 595, 'friends_count': 386, 'listed_count': 4, 'created_at': 'Tue Jan 12 22:04:48 +0000 2016', 'favourites_count': 11507, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': True, 'verified': False, 'statuses_count': 9274, 'lang': 'es', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://a ...

# %% [markdown]
# ## 3. Conectarse al SGBD Mongo

# %% [markdown]
# - Conectarse a Mongo desde Python utilizando la librería adecuada

# %%
from pymongo import MongoClient
client = MongoClient()
client = MongoClient('localhost', 27017)
db=client.taller
colection=db.dataset

# %% [markdown]
# ## 4. Escribir datos de Twitter en una Base de Datos Mongo

# %%
posts= db.posts
import pprint
pprint.pprint(posts.find_one(Json))
posts.insert_one(Json).inserted_id
# Out:
# None
# ObjectId('5acbd1fca3d4f52687c73afe')
